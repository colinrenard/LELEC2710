# %%
import kwant
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# C:\Users\renar\anaconda3\lib\site-packages\kwant\solvers\default.py:16: RuntimeWarning: MUMPS is not available, SciPy built-in solver will be used as a fallback. Performance can be very poor in this case.
#   warnings.warn("MUMPS is not available, "

# %%
# Fundamental constants

pi = np.pi
h = 6.626069e-34    # Planck constant (Js)
e = 1.602e-19      # electron charge (C)
c = 299792458       # Light celerity (m/s)
kB = 1.3806503e-23  # Boltzmann constant (kg m2/Ks2)
m_e = 9.1e-31       # electron mass (kg)
vf = 1e6            # Fermi velocity (m/s)
hbar = h/(2*pi)     # Reduced planck constant

sin_30 = np.sin(pi/6)
cos_30 = np.cos(pi/6)

epsilon_0 = 8.85e-12  # Vacuum permittivity (F/m)
epsilon_hBN = 3
epsilon_Ox = 3.8

# %%
# Definition of the potential
db = 20e-9 # bottom hBN layer thickness (m)
dOx = 285e-9 # substrate thickness (m)

Cbg = epsilon_0 / (db/epsilon_hBN + dOx/epsilon_Ox)

# We do not have a precise function for the capacitance linked with the CNT, so we use the approximation they provide
r_cnt = 1e-9 # CNT radius (m)
dt = 4e-9 # top hBN thickness (m)
ht = dt + r_cnt
at = np.sqrt(ht**2 - r_cnt**2)
kappa = (ht+at)**2/r_cnt**2

# Here, epsilon_r is set to have a curve resembling the simulation in the article (Ccnt/e evaluated at 0 is around 2.5e12 cm^-2 V^-1)
def computeCcnt(y, epsilon_r=2.5):
    return epsilon_0*epsilon_r*4*at/((y**2+at**2)*np.log(kappa)) # Try log10 if it does not work

# def potential(site, Vcnt, Vbg):
#     (x, y) = site.pos
#     Ccnt = computeCcnt(y*a*1e-9)
#     n = (Cbg*Vbg + Ccnt*Vcnt)/e
#     U = -np.sign(n)*hbar*vf*np.sqrt(pi*np.abs(n))
#     return U/e # Divide by e to obtain electronVolts

def potential(site, Vcnt, Vbg):
    (x, y) = site.pos
    if -W/10 < y < W/10:
        return Vcnt
    else:
        return 0

def potential(site):
    (x, y) = site.pos
    if -W/10 < y < W/10:
        return 0
    else:
        return 0

# %%
# System maker
a0 = 1/(4*np.sqrt(3))
t0 = 3.0

s = 10
a = a0*s
t = t0/s
W = int(360 / a)
L = int(360 / a) 
W_lead = int(50 / a)
L_lead = int(360 / a)

def rect(pos):
    x, y = pos
    if -L/2 < x < L/2 and -W/2 < y < W/2:
        return True
    else:
        return False 

def lead_horizontal(pos, L=L_lead):
    x, y = pos
    return -L//2 < x < L//2

def lead_vertical(pos, W=W_lead):
    x, y = pos
    return -W//2 < y < W//2

def sys_builder_graph():

    graphene = kwant.lattice.general([(np.sqrt(3)*a, 0), (0, 3*a)], [(a*np.sqrt(3)/2, 0), (0, a/2), (0, 3*a/2)\
                                                                     , (a*np.sqrt(3)/2, 2*a)], norbs = 1)
    A, B, C, D = graphene.sublattices
    sys = kwant.Builder() 
    hoppings = (((0, 0), B, A), ((0, 0), C, B), ((0, 0), D, C), ((-1, 0), A, B), ((-1, 0), D, C),((0, 1), A, D)) # the function hopping is given on each edge
    sys[graphene.shape(rect, (0,0))] = potential
    sys[[kwant.builder.HoppingKind(*hopping) for hopping in hoppings]] = -t
    sys.eradicate_dangling()

     # Create leads
    
    sym0 = kwant.TranslationalSymmetry(graphene.vec((-1, 0)))
    lead0 = kwant.Builder(sym0)
    lead0[graphene.shape(lead_vertical, (0, 0))] = potential
    lead0[graphene.neighbors()]= -t
    lead0.eradicate_dangling()
    sys.attach_lead(lead0)

    sym1 = kwant.TranslationalSymmetry(graphene.vec((1, 0)))
    lead1 = kwant.Builder(sym1)
    lead1[graphene.shape(lead_vertical, (0, 0))] = potential
    lead1[graphene.neighbors()] = -t
    lead1.eradicate_dangling()
    sys.attach_lead(lead1)

    sym2 = kwant.TranslationalSymmetry(graphene.vec((0, 1)))
    lead2 = kwant.Builder(sym2)
    lead2[graphene.shape(lead_horizontal, (0, 0))] = 0 #potential
    lead2[graphene.neighbors()] = -t
    lead2.eradicate_dangling()
    sys.attach_lead(lead2)

    sym3 = kwant.TranslationalSymmetry(graphene.vec((0, -1)))
    lead3 = kwant.Builder(sym3)
    lead3[graphene.shape(lead_horizontal, (0, 0))] = 0 #potential
    lead3[graphene.neighbors()] = -t
    lead3.eradicate_dangling()
    sys.attach_lead(lead3)
    
    return sys

# %%
syst = sys_builder_graph()
kwant.plot(syst)
fsyst = syst.finalized()

# %%
### Plotting T as a function of the energy

VcntArray = np.linspace(3, 2000, 50)
T = np.zeros_like(VcntArray)

for i in range(len(T)):
    smatrix = kwant.smatrix(fsyst, energy=0, params=dict(Vcnt=VcntArray[i], Vbg=0))
    T[i] = smatrix.transmission(1, 0)

plt.plot(VcntArray, T)
plt.grid()
plt.xlabel("Vcnt")
plt.ylabel("T")
# Out:
# Text(0, 0.5, 'T')

# %%
E = np.linspace(0.01, 1, 100)
T = np.zeros_like(E)

for i in range(len(E)):
    smatrix = kwant.smatrix(fsyst, energy=E[i])
    T[i] = smatrix.transmission(1, 0)

plt.plot(E, T)
plt.grid()
plt.xlabel("E/t")
plt.ylabel("T")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\kwant\builder.py:1906, in _FinalizedBuilderMixin.hamiltonian(self, i, j, params, *args)
#    1905 try:
# -> 1906     value = value(site, *args)
#    1907 except Exception as exc:
#
# TypeError: potential() missing 2 required positional arguments: 'Vcnt' and 'Vbg'
#
# The above exception was the direct cause of the following exception:
#
# UserCodeError                             Traceback (most recent call last)
# Cell In [8], line 5
#       2 T = np.zeros_like(E)
#       4 for i in range(len(E)):
# ----> 5     smatrix = kwant.smatrix(fsyst, energy=E[i])
#       6     T[i] = smatrix.transmission(1, 0)
#       8 plt.plot(E, T)
#
# File ~\anaconda3\lib\site-packages\kwant\_common.py:72, in deprecate_parameter.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#      70 if sig.bind(*args, **kwargs).arguments.get(parameter_name):
#      71     warn()
# ---> 72 return f(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\kwant\solvers\common.py:371, in SparseSolver.smatrix(self, sys, energy, args, out_leads, in_leads, check_hermiticity, params)
#     368 if len(in_leads) == 0 or len(out_leads) == 0:
#     369     raise ValueError("No output is requested.")
# --> 371 linsys, lead_info = self._make_linear_sys(syst, in_leads, energy, args,
#     372                                           check_hermiticity, False,
#     373                                           params=params)
#     375 kept_vars = np.concatenate([coords for i, coords in
#     376                             enumerate(linsys.indices) if i in
#     377                             out_leads])
#     379 # Do not perform factorization if no calculation is to be done.
#
# File ~\anaconda3\lib\site-packages\kwant\solvers\common.py:162, in SparseSolver._make_linear_sys(self, sys, in_leads, energy, args, check_hermiticity, realspace, params)
#     160 if not syst.lead_interfaces:
#     161     raise ValueError('System contains no leads.')
# --> 162 lhs, norb = syst.hamiltonian_submatrix(args, sparse=True,
#     163                                        return_norb=True,
#     164                                        params=params)[:2]
#     165 lhs = getattr(lhs, 'to' + self.lhsformat)()
#     166 lhs = lhs - energy * sp.identity(lhs.shape[0], format=self.lhsformat)
#
# File ~\anaconda3\lib\site-packages\kwant\_common.py:72, in deprecate_parameter.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#      70 if sig.bind(*args, **kwargs).arguments.get(parameter_name):
#      71     warn()
# ---> 72 return f(*args, **kwargs)
#
# File kwant\_system.pyx:297, in kwant._system.hamiltonian_submatrix()
#
# File ~\anaconda3\lib\site-packages\kwant\builder.py:1914, in _FinalizedBuilderMixin.hamiltonian(self, i, j, params, *args)
#    1911                     msg = ('System is missing required arguments: ',
#    1912                            ', '.join(map('"{}"'.format, missing)))
#    1913                     raise TypeError(''.join(msg))
# -> 1914             _raise_user_error(exc, value)
#    1915 else:
#    1916     edge_id = self.graph.first_edge_id(i, j)
#
# File ~\anaconda3\lib\site-packages\kwant\builder.py:1836, in _raise_user_error(exc, func)
#    1833 def _raise_user_error(exc, func):
#    1834     msg = ('Error occurred in user-supplied value function "{0}".\n'
#    1835            'See the upper part of the above backtrace for more information.')
# -> 1836     raise UserCodeError(msg.format(func.__name__)) from exc
#
# UserCodeError: Error occurred in user-supplied value function "potential".
# See the upper part of the above backtrace for more information.
